# %% [markdown]
# <a href="https://colab.research.google.com/github/ShantanuSinghBankoti/Employee_satisfaction/blob/main/Employee_satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing the dataset**

# %%
data=pd.read_csv("Employee Satisfaction Index.csv")
data.head()
# Out:
#    serial    emp_id  age        Dept  ... awards certifications salary  satisfied
# 0       0    HR8270   28          HR  ...      1              0  86750          1
# 1       1  TECH1860   50  Technology  ...      2              1  42419          0
# 2       2  TECH6390   43  Technology  ...      2              0  65715          0
# 3       3   SAL6191   44       Sales  ...      0              0  29805          1
# 4       4    HR6734   33          HR  ...      5              0  29805          1
#
# [5 rows x 14 columns]

# %%
data.describe()
# Out:
#            serial         age  ...        salary   satisfied
# count  500.000000  500.000000  ...    500.000000  500.000000
# mean   249.500000   38.610000  ...  50416.056000    0.526000
# std    144.481833    9.438648  ...  23671.392661    0.499824
# min      0.000000   23.000000  ...  24076.000000    0.000000
# 25%    124.750000   30.000000  ...  29805.000000    0.000000
# 50%    249.500000   39.000000  ...  42419.000000    1.000000
# 75%    374.250000   47.000000  ...  65715.000000    1.000000
# max    499.000000   54.000000  ...  86750.000000    1.000000
#
# [8 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# serial              0
# emp_id              0
# age                 0
# Dept                0
# location            0
# education           0
# recruitment_type    0
# job_level           0
# rating              0
# onsite              0
# awards              0
# certifications      0
# salary              0
# satisfied           0
# dtype: int64

# %% [markdown]
# **Univariate Analysis**

# %%
plt.hist(x=data['age'],bins=100,alpha=.85,rwidth=.9)
# Out:
# (array([12.,  0.,  0., 19.,  0.,  0., 19.,  0.,  0., 19.,  0.,  0., 18.,
#          0.,  0.,  0., 15.,  0.,  0., 11.,  0.,  0., 17.,  0.,  0., 13.,
#          0.,  0.,  0., 10.,  0.,  0., 17.,  0.,  0., 14.,  0.,  0., 20.,
#          0.,  0., 12.,  0.,  0.,  0., 16.,  0.,  0.,  9.,  0.,  0., 22.,
#          0.,  0., 16.,  0.,  0.,  0., 19.,  0.,  0.,  9.,  0.,  0., 16.,
#          0.,  0., 18.,  0.,  0., 16.,  0.,  0.,  0., 17.,  0.,  0., 10.,
#          0.,  0., 13.,  0.,  0., 16.,  0.,  0.,  0., 21.,  0.,  0., 12.,
#          0.,  0., 15.,  0.,  0., 20.,  0.,  0., 19.]),
#  array([23.  , 23.31, 23.62, 23.93, 24.24, 24.55, 24.86, 25.17, 25.48,
#         25.79, 26.1 , 26.41, 26.72, 27.03, 27.34, 27.65, 27.96, 28.27,
#         28.58, 28.89, 29.2 , 29.51, 29.82, 30.13, 30.44, 30.75, 31.06,
#         31.37, 31.68, 31.99, 32.3 , 32.61, 32.92, 33.23, 33.54, 33.85,
#         34.16, 34.47, 34.78, 35.09, 35.4 , 35.71, 36.02, 36.33, 36.64,
# ...

# %%
plt.boxplot(data['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f608f0b4110>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f608ef2bd90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f608ef32dd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f608ef32890>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f608ef2b310>,
#   <matplotlib.lines.Line2D at 0x7f608ef2b850>]}

# %%
data['Dept'].value_counts().plot(kind='bar')

# %%
data['location'].value_counts().plot(kind='bar')

# %%
data['education'].value_counts().plot(kind='bar')

# %%
data['recruitment_type'].value_counts().plot(kind='bar')

# %%
data['job_level'].value_counts().plot(kind='bar')

# %%
data['rating'].value_counts().plot(kind='bar')

# %%
data['onsite'].value_counts().plot(kind='bar')

# %%
data['awards'].value_counts().plot(kind='bar')

# %%
data['certifications'].value_counts().plot(kind='bar')

# %%
plt.hist(x=data['salary'],alpha=.85,rwidth=.9)
# Out:
# (array([205.,   0.,  82.,   0.,   0.,   0., 110.,   0.,   0., 103.]),
#  array([24076. , 30343.4, 36610.8, 42878.2, 49145.6, 55413. , 61680.4,
#         67947.8, 74215.2, 80482.6, 86750. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data['salary'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f608ebc1dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f608ea01890>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f608ea098d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f608ea09390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f608ea7cdd0>,
#   <matplotlib.lines.Line2D at 0x7f608ea01350>]}

# %% [markdown]
# **Bivariate Analysis**

# %%
plt.scatter(data['age'], data['satisfied'],alpha=.2)
plt.show()

# %%
import seaborn as sns
sns.violinplot(x =data['Dept'], y =data['satisfied'])

# %%
HR = data.loc[(data["Dept"] == 'HR')]
Tech = data.loc[(data["Dept"] == 'Technology')]
Sales = data.loc[(data["Dept"] == 'Sales')]
Purch = data.loc[(data["Dept"] == 'Purchasing')]
Mrkt = data.loc[(data["Dept"] == 'Marketing')]

# %%
HR.groupby('satisfied').size().plot(kind='pie', autopct='%.2f')

# %%
Sales.groupby('satisfied').size().plot(kind='pie', autopct='%.2f')

# %%
Purch.groupby('satisfied').size().plot(kind='pie', autopct='%.2f')

# %%
Tech.groupby('satisfied').size().plot(kind='pie', autopct='%.2f')

# %%
Mrkt.groupby('satisfied').size().plot(kind='pie', autopct='%.2f')

# %%
sns.violinplot(x =data['location'], y =data['satisfied'])

# %%
sns.violinplot(x =data['education'], y =data['satisfied'])

# %%
sns.violinplot(x =data['recruitment_type'], y =data['satisfied'])

# %%
sns.violinplot(x =data['job_level'], y =data['satisfied'])

# %%
sns.violinplot(x =data['rating'], y =data['satisfied'])

# %%
sns.violinplot(x =data['onsite'], y =data['satisfied'])

# %%
sns.violinplot(x =data['awards'], y =data['satisfied'])

# %%
sns.violinplot(x =data['certifications'], y =data['satisfied'])

# %%
plt.scatter(data['salary'], data['satisfied'],alpha=.2)
plt.show()

# %%
sns.violinplot(x =data['salary'], y =data['satisfied'])

# %% [markdown]
# **Correlation check**

# %%
import seaborn as sns
plt.figure(figsize=(18,10))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Accent)
plt.show()

# %% [markdown]
# we can see strong correaltion between job and salary so we will drop one feature.

# %% [markdown]
# **Droping unwanted coloumns**

# %%
data=data.drop(columns=['serial','emp_id','salary'])

# %%
data.describe()
# Out:
#               age   job_level  ...  certifications   satisfied
# count  500.000000  500.000000  ...      500.000000  500.000000
# mean    38.610000    3.032000  ...        0.496000    0.526000
# std      9.438648    1.423738  ...        0.500485    0.499824
# min     23.000000    1.000000  ...        0.000000    0.000000
# 25%     30.000000    2.000000  ...        0.000000    0.000000
# 50%     39.000000    3.000000  ...        0.000000    1.000000
# 75%     47.000000    4.000000  ...        1.000000    1.000000
# max     54.000000    5.000000  ...        1.000000    1.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# **Creating dummy variable**

# %%
data=pd.get_dummies(data=data, columns=['Dept', 'location','education','recruitment_type'])
data.head()
# Out:
#    age  job_level  ...  recruitment_type_Referral  recruitment_type_Walk-in
# 0   28          5  ...                          1                         0
# 1   50          3  ...                          0                         1
# 2   43          4  ...                          1                         0
# 3   44          2  ...                          0                         0
# 4   33          2  ...                          0                         0
#
# [5 rows x 20 columns]

# %%
data=data.drop(columns=['Dept_HR','location_City','education_PG','recruitment_type_Referral'])

# %%
data.head()
# Out:
#    age  ...  recruitment_type_Walk-in
# 0   28  ...                         0
# 1   50  ...                         1
# 2   43  ...                         0
# 3   44  ...                         0
# 4   33  ...                         0
#
# [5 rows x 16 columns]

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=0)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# **Training the Naive Bayes model on the Training set**

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# **Predicting Test results**

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[60 28]
#  [ 0 37]]
# 0.776
